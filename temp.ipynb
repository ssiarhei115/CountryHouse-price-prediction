# %%
import pandas as pd
import category_encoders as ce

user_df = pd.read_csv('user_data.csv', index_col=0)
print(user_df.shape)
user_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       2 import category_encoders as ce
# ----> 4 user_df = pd.read_csv('user_data.csv', index_col=0)
#       5 print(user_df.shape)
#       6 user_df
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'user_data.csv'

# %%
ohe_list = ['Материал стен', 'Материал крыши', 'Отопление', 'Канализация', 'Электроснабжение', 'Вода','Область', 'Газ', 'Ремонт']
#user_df = pd.get_dummies(user_df,columns=ohe_list)
encoder = ce.OneHotEncoder(cols=ohe_list, use_cat_names=True)
add = encoder.fit_transform(user_df.loc[:,ohe_list])
user_df = pd.concat([user_df,add], axis=1)#.drop(ohe_list, axis=1)

user_df
# Out:
#       Баня  Сад  Хозпостройки  Рядом лес  Бассейн  Элитный коттедж
# user     1    1             1          0        0                1  \
#
#       house_area  house_year  liv_house_area  kitchen_area  ...       Ремонт
# user          30        1980              30            20  ...  евроотделка  \
#
#       Материал стен_дерево  Материал крыши_шифер Отопление_паровое г.
# user                     1                     1                    1  \
#
#      Канализация_есть Электроснабжение_есть Вода_сезонная Область_Минск
# user                1                     1             1             1  \
#
#      Газ_есть Ремонт_евроотделка
# user        1                  1
#
# [1 rows x 31 columns]

# %%
default = {
    'Сад':0, 
    'Хозпостройки':0, 
    'Рядом лес':0, 
    'Бассейн':0, 
    'Элитный коттедж':0,
    'house_area':0, 
    'house_year':0, 
    'liv_house_area':0, 
    'kitchen_area':0,
    'distance_house_district':0, 
    'distance_house_region':0,
    'distance_house_minsk':0, 
    'Материал стен_блок г/с':0,
    'Материал стен_дерево':0, 
    'Материал стен_сб-щитовой':0,
    'Материал крыши_черепица бит.':0, 
    'Материал крыши_черепица мет.':0,
    'Материал крыши_черепица мяг.':0, 
    'Материал крыши_шифер':0,
    'Отопление_нет':0, 
    'Отопление_паровое г.':0, 
    'Отопление_паровое т.':0,
    'Отопление_печь':0, 
    'Отопление_электрич.':0, 
    'Канализация_есть':0,
    'Канализация_местная':0, 
    'Канализация_нет':0, 
    'Электроснабжение_нет':0,
    'Вода_колодец':0, 
    'Вода_нет':0, 
    'Вода_сезонная':0, 
    'Вода_скважина':0,
    'Вода_центральн.':0, 
    'Область_Брест':0, 
    'Область_Витебск':0,
    'Область_Гомель':0, 
    'Область_Могилев':0, 
    'Газ_есть':0, 
    'Газ_нет':0,
    'Ремонт_евроотделка':0}

# %%
for col in user_df.columns:
    if col not in default.keys():
        user_df = user_df.drop([col], axis=1)

# %%
user_df.head()
# Out:
#       Сад  Хозпостройки  Рядом лес  Бассейн  Элитный коттедж  house_area
# user    1             1          0        0                1          30  \
#
#       house_year  liv_house_area  kitchen_area  distance_house_district
# user        1980              30            20                       20  \
#
#       distance_house_region  distance_house_minsk  Материал стен_дерево
# user                     30                    50                     1  \
#
#       Материал крыши_шифер  Отопление_паровое г.  Канализация_есть
# user                     1                     1                 1  \
#
#       Вода_сезонная  Газ_есть  Ремонт_евроотделка
# user              1         1                   1

# %%
default_df = pd.DataFrame(default, index=['default'])
default_df
# Out:
#          Сад  Хозпостройки  Рядом лес  Бассейн  Элитный коттедж  house_area
# default    0             0          0        0                0           0  \
#
#          house_year  liv_house_area  kitchen_area  distance_house_district
# default           0               0             0                        0  \
#
#          ...  Вода_сезонная  Вода_скважина  Вода_центральн.  Область_Брест
# default  ...              0              0                0              0  \
#
#          Область_Витебск  Область_Гомель  Область_Могилев  Газ_есть  Газ_нет
# default                0               0                0         0        0  \
#
#          Ремонт_евроотделка
# default                   0
#
# [1 rows x 40 columns]

# %%
concat_df =pd.concat([default_df, user_df], axis=0).fillna(0)
concat_df.loc['sum', :] = concat_df.sum()
concat_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 concat_df =pd.concat([default_df, user_df], axis=0).fillna(0)
#       2 concat_df.loc['sum', :] = concat_df.sum()
#       3 concat_df
#
# NameError: name 'pd' is not defined
